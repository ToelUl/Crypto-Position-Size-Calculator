# %%
# !git clone https://github.com/ToelUl/Crypto-Position-Size-Calculator.git
# !cp -r Crypto-Position-Size-Calculator/* ./
# !python -m pip install -q streamlit pandas
# !npm install -g localtunnel

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# !nohup python -m streamlit run app.py \--server.address=0.0.0.0 \--server.port=8501 \--server.headless=true \--browser.gatherUsageStats=false \--server.enableCORS=false \--server.enableXsrfProtection=false > /content/logs.txt 2>&1 &

# !echo "waiting for Streamlit to start..."
# !while ! curl -s http://localhost:8501 > /dev/null; do sleep 1; done
# !echo "✅ Streamlit started successfully!"

# %% [markdown]
# ### Fist try using Cloudflare Tunnel, it is high probability that it don't work, but still trying it first.

# %%
# !cloudflared tunnel --url http://localhost:8501 --no-autoupdate

# %% [markdown]
# ### If Cloudflare Tunnel doesn't work, stop the code block above and try using LocalTunnel, it is still high probability that it don't work, but still trying it.

# %%
# !nohup python -m streamlit run app.py \--server.address=0.0.0.0 \--server.port=8501 \--server.headless=true \--browser.gatherUsageStats=false \--server.enableCORS=false \--server.enableXsrfProtection=false > /content/logs.txt 2>&1 &

# !echo "waiting for Streamlit to start..."
# !while ! curl -s http://localhost:8501 > /dev/null; do sleep 1; done
# !echo "✅ Streamlit started successfully!"

# %%
# !npx localtunnel --port 8501

# %% [markdown]
# ### If both Cloudflare Tunnel and LocalTunnel don't work, stop the code block above and try using Cloudflare Tunnel again, usually it will work in the second try, if it still doesn't work, just keep trying until it works, it is really weird but it is what it is.

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# !nohup python -m streamlit run app.py \--server.address=0.0.0.0 \--server.port=8501 \--server.headless=true \--browser.gatherUsageStats=false \--server.enableCORS=false \--server.enableXsrfProtection=false > /content/logs.txt 2>&1 &

# !echo "waiting for Streamlit to start..."
# !while ! curl -s http://localhost:8501 > /dev/null; do sleep 1; done
# !echo "✅ Streamlit started successfully!"

# %%
# !cloudflared tunnel --url http://localhost:8501 --no-autoupdate
